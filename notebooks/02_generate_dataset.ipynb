# %%
from brainfield_operator.data import SimulationConfig, generate_dataset

cfg = SimulationConfig(nx=64, ny=64, length=0.20, seed=42)

generate_dataset(
    n_samples=200,
    output_dir="../data/brainfield",
    config=cfg,
    prefix="sample",
    start_index=0,
)
