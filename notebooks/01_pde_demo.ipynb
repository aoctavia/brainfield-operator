# %%
import numpy as np
import matplotlib.pyplot as plt

from brainfield_operator.data import SimulationConfig, simulate_single_sample
from brainfield_operator.visualization.plots import plot_potential_map, plot_field_quiver

cfg = SimulationConfig(nx=64, ny=64, length=0.20, seed=1)
sample = simulate_single_sample(cfg)

V = sample["V"]
Ex = sample["Ex"]
Ey = sample["Ey"]

plot_potential_map(V, title="Example PDE Solution (V)", save_path=None)
plot_field_quiver(Ex, Ey, step=4, save_path=None)
